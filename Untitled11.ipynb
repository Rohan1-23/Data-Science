# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

data1=pd.read_csv("Book1.csv")  
data1.head()
# Out:
#   Z numbers for the fuzzy rates Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0     A (restriction component)        NaN         NaN         NaN
# 1          Linguistic Variable       TrFNs         NaN         NaN
# 2                Very Poor (VP)          0         0.0         1.0
# 3                      Poor (P)          1         2.0         2.0
# 4              Medium Poor (MP)          2         3.0         4.0
#
#    Unnamed: 4                 Unnamed: 5 Unnamed: 6  Unnamed: 7  Unnamed: 8
# 0         NaN  B (reliability component)        NaN         NaN         NaN
# 1         NaN        Linguistic Variable      TrFNs         NaN         NaN
# 2         2.0               Vey Low (VL)          0         0.0         0.1
# 3         3.0                    Low (L)          0         0.1         0.3
# 4         5.0            Medium Low (ML)        0.1         0.3         0.5
